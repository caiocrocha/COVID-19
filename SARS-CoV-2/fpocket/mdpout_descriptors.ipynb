# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('mdpout_descriptors.txt', delim_whitespace=True)

# %%
data
# Out:
#       snapshot  pock_volume  pock_asa  pock_pol_asa  pock_apol_asa  \
# 0            1      1104.41    672.76        352.73         320.02
# 1            2      1715.91   1006.30        520.83         485.47
# 2            3      1494.76    852.19        371.56         480.64
# 3            4      1685.72    985.57        495.27         490.30
# 4            5      1292.16    725.45        406.64         318.81
# ...        ...          ...       ...           ...            ...
# 1995      1996      1366.16    834.86        366.30         468.56
# 1996      1997      1652.36   1030.92        518.89         512.03
# 1997      1998      1634.01   1042.30        537.52         504.79
# 1998      1999      1390.50    786.91        410.13         376.78
# 1999      2000      1265.23    831.36        465.45         365.91
#
#       pock_asa22  pock_pol_asa22  pock_apol_asa22  nb_AS  mean_as_ray  ...  \
# 0         442.39          241.70           200.69    248         4.04  ...
# 1         681.14          348.56           332.57    385         4.20  ...
# 2         598.50          241.08           357.42    342         4.17  ...
# 3         666.97          376.44           290.52    480         4.14  ...
# 4         459.79          282.03           177.76    331         4.23  ...
# ...          ...             ...              ...    ...          ...  ...
# 1995      558.77          207.09           351.69    517         4.04  ...
# 1996      700.88          381.69           319.19    590         4.18  ...
# 1997      594.22          328.54           265.68    526         4.02  ...
# 1998      468.14          223.49           244.65    390         4.00  ...
# 1999      469.97          236.79           233.18    382         4.02  ...
#
#       LEU  LYS  MET  PHE  PRO  SER  THR  TRP  TYR  VAL
# 0       0    4    1    0    3    1    0    1    0    0
# 1       0    4    2    0    4    2    1    2    0    1
# 2       0    4    2    0    4    0    1    2    0    2
# 3       0    4    2    1    5    1    2    2    0    2
# 4       0    4    2    0    3    0    1    1    0    2
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 1995    0    4    2    1    3    0    0    2    0    3
# 1996    0    4    2    1    3    1    0    2    0    2
# 1997    0    4    2    1    4    1    0    2    0    3
# 1998    0    4    2    1    3    1    1    2    0    2
# 1999    0    4    1    1    2    1    0    1    0    2
#
# [2000 rows x 42 columns]

# %%
fig, ax = plt.subplots(2, 2, figsize=(12,8))
for i, d in enumerate(['pock_volume','pock_asa','pock_pol_asa','pock_apol_asa']):
    sns.lineplot(data=data, x='snapshot', y=d, ax=ax[i//2,i%2])
    sns.lineplot(data=data, x='snapshot', y=data[d].rolling(window=140).mean(), ax=ax[i//2,i%2])
    ax[i//2,i%2].set_title(f'{d} rolling mean')
fig.tight_layout()
plt.show()

# %%
sns.violinplot(data['pock_volume'])

# %% [markdown]
# # Análise de cluster

# %%
sns.heatmap(data[['pock_volume','pock_asa','pock_pol_asa','pock_apol_asa']].corr(), annot=True, cmap='Blues')

# %%
fig, ax = plt.subplots(2, 2, figsize=(12,8))
for i, d in enumerate(['pock_volume','pock_asa','pock_pol_asa','pock_apol_asa']):
    sns.distplot(data[d], ax=ax[i//2,i%2])
    ax[i//2,i%2].set_title(f'{d} distribution plot')
fig.tight_layout()
plt.show()

# %%
2000/3
# Out:
# 666.6666666666666

# %%
data['cluster'] = 2
Q1 = data['pock_volume'].quantile(0.33)
data.loc[data['pock_volume'] < Q1,'cluster'] = 1
Q3 = data['pock_volume'].quantile(0.66)
data.loc[data['pock_volume'] > Q3,'cluster'] = 3

# %%
data['cluster'] = 2
Q1 = 1000
data.loc[data['pock_volume'] < Q1,'cluster'] = 1
Q3 = 1500
data.loc[data['pock_volume'] > Q3,'cluster'] = 3

# %%
fig, ax = plt.subplots(3, figsize=(10,8))
for i, d in enumerate(['pock_asa','pock_pol_asa','pock_apol_asa']):
    for cl in range(1, 4):
        sns.distplot(data.query('cluster == @cl')[d], ax=ax[i], label=cl)
    ax[i].legend(title='cluster')
fig.tight_layout()
plt.show()

# %%
sns.catplot(kind='count', data=data, x='cluster')

# %%
data['cluster'].value_counts()
# Out:
# 2    1064
# 3     839
# 1      97
# Name: cluster, dtype: int64

# %%
fig, ax = plt.subplots(2, 2, figsize=(12,8))
for i, d in enumerate(['pock_volume','pock_asa','pock_pol_asa','pock_apol_asa']):
    for cl in range(1, 4):
        df = data.query('cluster == @cl')
        ax[i//2,i%2].plot(df['snapshot'], df[d], label=cl)
        ax[i//2,i%2].plot(df['snapshot'], df[d].rolling(window=140).mean(), color='black')
    ax[i//2,i%2].set_title(f'{d} rolling mean')
    ax[i//2,i%2].legend(title='cluster')
fig.tight_layout()
plt.show()
